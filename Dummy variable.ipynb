# %% [markdown]
# #### Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### load dataset

# %%
df = pd.read_csv('/Dataset/house_price.csv')
df
# Out:
#           Zone  Area(sq-ft)  Price(Taka)
# 0        Dhaka         2104       399900
# 1        Dhaka         1600       329900
# 2        Dhaka         2400       369000
# 3        Dhaka         1416       232000
# 4        Dhaka         3000       539900
# 5   Chittagong         1985       299900
# 6   Chittagong         1534       314900
# 7   Chittagong         1427       198999
# 8   Chittagong         1380       212000
# 9   Chittagong         1494       242500
# 10      Khulna         1940       239999
# 11      Khulna         2000       347000
# 12      Khulna         1890       329999
# 13      Khulna         4478       699900

# %%
df.dtypes
# Out:
# Zone           object
# Area(sq-ft)     int64
# Price(Taka)     int64
# dtype: object

# %%
df.Zone.unique()
# Out:
# array(['Dhaka', 'Chittagong', 'Khulna'], dtype=object)

# %% [markdown]
# Our Zone columns is object type data

# %% [markdown]
# #### From categorical variables to dummy variables via pandas

# %%
dummies = pd.get_dummies(df.Zone)
dummies
# Out:
#     Chittagong  Dhaka  Khulna
# 0            0      1       0
# 1            0      1       0
# 2            0      1       0
# 3            0      1       0
# 4            0      1       0
# 5            1      0       0
# 6            1      0       0
# 7            1      0       0
# 8            1      0       0
# 9            1      0       0
# 10           0      0       1
# 11           0      0       1
# 12           0      0       1
# 13           0      0       1

# %% [markdown]
# #### Pair df and dummies using the concat method of pandas

# %%
df_dummies = pd.concat([df,dummies],axis='columns')
df_dummies
# Out:
#           Zone  Area(sq-ft)  Price(Taka)  Chittagong  Dhaka  Khulna
# 0        Dhaka         2104       399900           0      1       0
# 1        Dhaka         1600       329900           0      1       0
# 2        Dhaka         2400       369000           0      1       0
# 3        Dhaka         1416       232000           0      1       0
# 4        Dhaka         3000       539900           0      1       0
# 5   Chittagong         1985       299900           1      0       0
# 6   Chittagong         1534       314900           1      0       0
# 7   Chittagong         1427       198999           1      0       0
# 8   Chittagong         1380       212000           1      0       0
# 9   Chittagong         1494       242500           1      0       0
# 10      Khulna         1940       239999           0      0       1
# 11      Khulna         2000       347000           0      0       1
# 12      Khulna         1890       329999           0      0       1
# 13      Khulna         4478       699900           0      0       1

# %% [markdown]
# #### Now no need to Zone columns

# %%
df_dummies.drop('Zone',axis='columns',inplace=True)
df_dummies
# Out:
#     Area(sq-ft)  Price(Taka)  Chittagong  Dhaka  Khulna
# 0          2104       399900           0      1       0
# 1          1600       329900           0      1       0
# 2          2400       369000           0      1       0
# 3          1416       232000           0      1       0
# 4          3000       539900           0      1       0
# 5          1985       299900           1      0       0
# 6          1534       314900           1      0       0
# 7          1427       198999           1      0       0
# 8          1380       212000           1      0       0
# 9          1494       242500           1      0       0
# 10         1940       239999           0      0       1
# 11         2000       347000           0      0       1
# 12         1890       329999           0      0       1
# 13         4478       699900           0      0       1

# %% [markdown]
# #### Now we will omit the Khulna column on the far right. Because if Chittagong = 0, and Dhaka = 0, we can say that the region will be Khulna. This will allow the linear regression to work properly.

# %%
df_dummies.drop('Khulna', axis='columns', inplace=True)
df_dummies
# Out:
#     Area(sq-ft)  Price(Taka)  Chittagong  Dhaka
# 0          2104       399900           0      1
# 1          1600       329900           0      1
# 2          2400       369000           0      1
# 3          1416       232000           0      1
# 4          3000       539900           0      1
# 5          1985       299900           1      0
# 6          1534       314900           1      0
# 7          1427       198999           1      0
# 8          1380       212000           1      0
# 9          1494       242500           1      0
# 10         1940       239999           0      0
# 11         2000       347000           0      0
# 12         1890       329999           0      0
# 13         4478       699900           0      0

# %% [markdown]
# #### Model setup

# %%
X = df_dummies.drop('Price(Taka)',axis='columns')
y = df_dummies['Price(Taka)']

# %%
X
# Out:
#     Area(sq-ft)  Chittagong  Dhaka
# 0          2104           0      1
# 1          1600           0      1
# 2          2400           0      1
# 3          1416           0      1
# 4          3000           0      1
# 5          1985           1      0
# 6          1534           1      0
# 7          1427           1      0
# 8          1380           1      0
# 9          1494           1      0
# 10         1940           0      0
# 11         2000           0      0
# 12         1890           0      0
# 13         4478           0      0

# %%
y
# Out:
# 0     399900
# 1     329900
# 2     369000
# 3     232000
# 4     539900
# 5     299900
# 6     314900
# 7     198999
# 8     212000
# 9     242500
# 10    239999
# 11    347000
# 12    329999
# 13    699900
# Name: Price(Taka), dtype: int64

# %% [markdown]
# ##### Import sklearn Linear Regression Library

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.predict([[2700,0,0]]) # 2700 sqr ft home in Khulna
# Out:
# array([423589.31409093])

# %%
lr.score(X, y)
# Out:
# 0.9232329089668183
