# %% [markdown]
# #### import libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ##### Difference betwen nominal and ordinal

# %% [markdown]
# <img src="https://raw.githubusercontent.com/msjahid/Machine-Learning-Glossary/main/images/nominal%20%26%20ordinal.png">

# %% [markdown]
# <img src="https://raw.githubusercontent.com/msjahid/Machine-Learning-Glossary/main/images/encoding.png">

# %% [markdown]
# #### Read excel data

# %%
df = pd.read_excel('/Dataset/district-wise-confirmed.2020.xlsx')

# %%
df.head()
# Out:
#      Division  Confirmed_cases \nUpto 05 April  \
# 0       Dhaka                               54
# 1  Chittagong                                1
# 2       Dhaka                               11
# 3    Rajshahi                                0
# 4  Chittagong                                1
#
#    Confirmed_cases \nUpto 06 April  Confirmed_cases \nUpto 07 April  \
# 0                               64                               90
# 1                                1                                3
# 2                               23                               38
# 3                                0                                0
# 4                                1                                2
#
#    Confirmed_cases Upto 08 April  Confirmed_cases Upto 09 April  \
# 0                            129                            209
# 1                              3                              9
# 2                             46                             59
# ...

# %% [markdown]
# ##### Division types is object

# %%
df.dtypes
# Out:
# Division                            object
# Confirmed_cases \nUpto 05 April      int64
# Confirmed_cases \nUpto 06 April      int64
# Confirmed_cases \nUpto 07 April      int64
# Confirmed_cases Upto 08 April        int64
# Confirmed_cases Upto 09 April        int64
# Confirmed_cases Upto 11 April        int64
# Confirmed_cases Upto 13 April        int64
# Confirmed_cases Upto 14 April        int64
# Confirmed_cases Upto 15 April        int64
# Confirmed_cases Upto 16 April        int64
# Confirmed_cases Upto 17 April        int64
# Confirmed_cases Upto 18 April        int64
# Confirmed_cases Upto 19 April        int64
# Confirmed_cases Upto 20 April        int64
# Confirmed_cases Upto 21 April        int64
# Confirmed_cases Upto 22 April        int64
# Confirmed_cases Upto 23 April      float64
# Recovered_cases\nUpto 23 April       int64
# Confirmed_cases Upto 24 April        int64
# Confirmed_cases Upto 25 April        int64
# Confirmed_cases Upto 26 April        int64
# ...

# %% [markdown]
# ### Label Encoding using Python

# %%
# df['Division'].nunique()
df['Division'].unique()
# Out:
# array(['Dhaka', 'Chittagong', 'Rajshahi', 'Sylhet', 'Khulna',
#        'Mymensingh', 'Barisal', 'Rangpur'], dtype=object)

# %% [markdown]
# ##### "Division" need to convert object to a category type with the help of pandas

# %%
df['Division'] = df['Division'].astype('category')
df.dtypes
# Out:
# Division                           category
# Confirmed_cases \nUpto 05 April       int64
# Confirmed_cases \nUpto 06 April       int64
# Confirmed_cases \nUpto 07 April       int64
# Confirmed_cases Upto 08 April         int64
# Confirmed_cases Upto 09 April         int64
# Confirmed_cases Upto 11 April         int64
# Confirmed_cases Upto 13 April         int64
# Confirmed_cases Upto 14 April         int64
# Confirmed_cases Upto 15 April         int64
# Confirmed_cases Upto 16 April         int64
# Confirmed_cases Upto 17 April         int64
# Confirmed_cases Upto 18 April         int64
# Confirmed_cases Upto 19 April         int64
# Confirmed_cases Upto 20 April         int64
# Confirmed_cases Upto 21 April         int64
# Confirmed_cases Upto 22 April         int64
# Confirmed_cases Upto 23 April       float64
# Recovered_cases\nUpto 23 April        int64
# Confirmed_cases Upto 24 April         int64
# Confirmed_cases Upto 25 April         int64
# ...

# %% [markdown]
# ##### access the codes of the categories

# %%
df['Division'] = df['Division'].cat.codes
df
# Out:
#     Division  Confirmed_cases \nUpto 05 April  \
# 0          2                               54
# 1          1                                1
# 2          2                               11
# 3          5                                0
# 4          1                                1
# ..       ...                              ...
# 59         6                                0
# 60         6                                0
# 61         6                                0
# 62         7                                0
# 63         6                                0
#
#     Confirmed_cases \nUpto 06 April  Confirmed_cases \nUpto 07 April  \
# 0                                64                               90
# 1                                 1                                3
# 2                                23                               38
# 3                                 0                                0
# ...

# %%
df['Division'].unique()
# Out:
# array([2, 1, 5, 7, 3, 4, 0, 6], dtype=int8)

# %% [markdown]
# ### Label Encoding in scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %% [markdown]
# #### Read data onces more

# %%
data = pd.read_excel('/Dataset/district-wise-confirmed.2020.xlsx')

# %%
data["Division"] = le.fit_transform(data["Division"])
data
# Out:
#     Division  Confirmed_cases \nUpto 05 April  \
# 0          2                               54
# 1          1                                1
# 2          2                               11
# 3          5                                0
# 4          1                                1
# ..       ...                              ...
# 59         6                                0
# 60         6                                0
# 61         6                                0
# 62         7                                0
# 63         6                                0
#
#     Confirmed_cases \nUpto 06 April  Confirmed_cases \nUpto 07 April  \
# 0                                64                               90
# 1                                 1                                3
# 2                                23                               38
# 3                                 0                                0
# ...

# %%
data['Division'].unique()
# Out:
# array([2, 1, 5, 7, 3, 4, 0, 6])
